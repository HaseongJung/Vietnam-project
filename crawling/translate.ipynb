# %%
#!pip install googletrans==4.0.0-rc1

# %%
import pandas as pd
import numpy as np

from googletrans import Translator
options = ['text', 'file']

from tqdm import tqdm
tqdm.pandas() # tqdm 전용 pandas

import time
import random as rd

# %%
df = pd.read_csv("./mergedDataset3.csv")
df.drop(axis=1, columns=['Unnamed: 0'], inplace=True)
df
# Out:
#                                              name     category  \
# 0                        Cardi Pizzeria Bach Dang     American
# 1    Ca Chuon Co Vietnamese - Seafood Restaurant.         Cafe
# 2                      Bistecca Restaurant Danang      Italian
# 3                             3 Big - Nướng & Lẩu        Pizza
# 4                      Thìa Gỗ Restaurant Da Nang   Vietnamese
# ..                                            ...          ...
# 582            Lang Ca - Fresh Seafood Restaurant   Vietnamese
# 583                             Cua Do Restaurant      Seafood
# 584             SOHO Buffet & Alacarte Restaurant     Japanese
# 585            Danang Tower Steakhouse & Soju Bar   Steakhouse
# 586                                   Burger King  Quick Bites
#
#                                            description  \
# 0    Premium Steak & Pizza Certified Imported Steak...
# 1    Ca Chuon Co, ('flying fish') a modern stylish ...
# 2    Bistecca – Italian restaurant offering the ori...
# 3    3 BiG - Nướng & Lẩu Nhà hàng BBQ - Thịt nướng ...
# 4                                                  NaN
# ..                                                 ...
# 582                                                NaN
# 583                                                NaN
# 584  As the world of food up to nearly 300 dishes i...
# 585  From the mouthwatering seafood to the tender g...
# 586                                                NaN
#
#                                                   time  \
# 0    ['Sun:12:00 AM - 11:59 PM', 'Mon:12:00 AM - 11...
# 1    ['Sun:06:00 AM - 10:00 PM', 'Mon:06:00 AM - 10...
# 2    ['Sun:06:00 AM - 10:00 PM', 'Mon:06:00 AM - 10...
# 3    ['Sun:11:00 AM - 11:00 PM', 'Mon:11:00 AM - 10...
# 4    ['Sun:10:00 AM - 10:00 PM', 'Mon:10:00 AM - 10...
# ..                                                 ...
# 582                                                NaN
# 583                                                NaN
# 584  ['Sun : 10:30 AM - 10:00 PM', 'Mon : 10:30 AM ...
# 585                                                NaN
# 586                                                NaN
#
#                                                    URL priceLow priceHigh  \
# 0    https://www.tripadvisor.com//Restaurant_Review...      NaN       NaN
# 1    https://www.tripadvisor.com//Restaurant_Review...  ₩12,953   ₩38,860
# 2    https://www.tripadvisor.com//Restaurant_Review...   ₩3,886   ₩64,767
# 3    https://www.tripadvisor.com//Restaurant_Review...      NaN       NaN
# 4    https://www.tripadvisor.com//Restaurant_Review...   ₩2,124   ₩26,554
# ..                                                 ...      ...       ...
# 582  https://www.tripadvisor.com//Restaurant_Review...      NaN       NaN
# 583  https://www.tripadvisor.com//Restaurant_Review...      NaN       NaN
# 584  https://www.tripadvisor.com//Restaurant_Review...      NaN       NaN
# 585  https://www.tripadvisor.com//Restaurant_Review...  ₩11,654   ₩87,403
# 586  https://www.tripadvisor.com//Restaurant_Review...      NaN       NaN
#
#                                                reviews  \
# 0    ['I came in for pizza because they look like t...
# 1    ["I was looking for some decent seafoods resta...
# 2    ['Beautiful dinner and great service! All meal...
# 3    ['Great service. Good price and good food. The...
# 4    ['Quynh was our server and took great care of ...
# ..                                                 ...
# 582  ['Services not good enough.\nThe guy at fish s...
# 583  ["This place was recommended by my guide becau...
# 584  ['Staff need to improve the service & english ...
# 585  ["Nice view. The first time I have been here w...
# 586  ['This Burger King is outrageously expensive a...
#
#                                                 adress rating  \
# 0    124 Bạch Đằng, Hải Châu, Đà Nẵng, Da Nang Vietnam   5.0
# 1    99 Vo Nguyen Giap Street Ngu Hanh Son District...   5.0
# 2    20 Dong Da 7F New Orient Hotel, Thuan Phuoc Wa...   5.0
# 3    134 Phan Châu Trinh, Phước Ninh, Hải Châu, Đà ...   5.0
# 4     53 Phan Thuc Duyen, My An, Da Nang 50507 Vietnam   5.0
# ..                                                 ...    ...
# 582  Lot 26 Vo Nguyen Giap Street My An Ward, Ngu H...   2.5
# 583  Cua Do Restaurant 233 a Nguyen Van Thoai Stree...   2.5
# 584          Lot 1, Street 2/9, Da Nang 550000 Vietnam   2.5
# 585  Đ. Trần Hưng Đạo 37/F, Vinpearl Condotel River...   1.5
# 586     Da Nang Airport Hai Chau Dist, Da Nang Vietnam   2.0
#
#                       TEL                                             images
# 0            +84989232315  ['https://media-cdn.tripadvisor.com/media/phot...
# 1        +84 236 3919 999  ['https://media-cdn.tripadvisor.com/media/phot...
# 2        +84 236 3828 828  ['https://media-cdn.tripadvisor.com/media/phot...
# 3        +84 236 3569 000  ['https://media-cdn.tripadvisor.com/media/phot...
# 4    Improve this listing  ['https://media-cdn.tripadvisor.com/media/vide...
# ..                    ...                                                ...
# 582      +84 98 331 13 68  ['https://media-cdn.tripadvisor.com/media/phot...
# 583      +84 98 316 15 16  ['https://media-cdn.tripadvisor.com/media/phot...
# 584      +84 90 868 57 89  ['https://media-cdn.tripadvisor.com/media/phot...
# 585       +(84)0896623737  ['https://media-cdn.tripadvisor.com/media/phot...
# 586      +84 511 3539 003  ['https://media-cdn.tripadvisor.com/media/phot...
#
# [587 rows x 12 columns]

# %%
# Make a new column for each language
df.insert(2, "categoryEg", df['category'])
df.insert(3, "categoryKo", df['category'])
df.insert(4, "categoryVi", df['category'])
df.drop(axis=1, columns=['category'], inplace=True)

df.insert(5, "descriptionEg", df['description'])
df.insert(6, "descriptionKo", df['description'])
df.insert(7, "descriptionVi", df['description'])
df.drop(axis=1, columns=['description'], inplace=True)

## adress
df.insert(12, "addressEg", df['adress'])
df.insert(13, "addressKo", df['adress'])
df.insert(14, "addressVi", df['adress'])
df.drop(axis=1, columns=['adress'], inplace=True)
print("------------------------------After Insert------------------------------")
print(df.columns)

df.head()
# Out:
#                                            name  categoryEg  categoryKo  \
# 0                      Cardi Pizzeria Bach Dang    American    American
# 1  Ca Chuon Co Vietnamese - Seafood Restaurant.        Cafe        Cafe
# 2                    Bistecca Restaurant Danang     Italian     Italian
# 3                           3 Big - Nướng & Lẩu       Pizza       Pizza
# 4                    Thìa Gỗ Restaurant Da Nang  Vietnamese  Vietnamese
#
#    categoryVi                                      descriptionEg  \
# 0    American  Premium Steak & Pizza Certified Imported Steak...
# 1        Cafe  Ca Chuon Co, ('flying fish') a modern stylish ...
# 2     Italian  Bistecca – Italian restaurant offering the ori...
# 3       Pizza  3 BiG - Nướng & Lẩu Nhà hàng BBQ - Thịt nướng ...
# 4  Vietnamese                                                NaN
#
#                                        descriptionKo  \
# 0  Premium Steak & Pizza Certified Imported Steak...
# 1  Ca Chuon Co, ('flying fish') a modern stylish ...
# 2  Bistecca – Italian restaurant offering the ori...
# 3  3 BiG - Nướng & Lẩu Nhà hàng BBQ - Thịt nướng ...
# 4                                                NaN
#
#                                        descriptionVi  \
# 0  Premium Steak & Pizza Certified Imported Steak...
# 1  Ca Chuon Co, ('flying fish') a modern stylish ...
# 2  Bistecca – Italian restaurant offering the ori...
# 3  3 BiG - Nướng & Lẩu Nhà hàng BBQ - Thịt nướng ...
# 4                                                NaN
#
#                                                 time  \
# 0  ['Sun:12:00 AM - 11:59 PM', 'Mon:12:00 AM - 11...
# 1  ['Sun:06:00 AM - 10:00 PM', 'Mon:06:00 AM - 10...
# 2  ['Sun:06:00 AM - 10:00 PM', 'Mon:06:00 AM - 10...
# 3  ['Sun:11:00 AM - 11:00 PM', 'Mon:11:00 AM - 10...
# 4  ['Sun:10:00 AM - 10:00 PM', 'Mon:10:00 AM - 10...
#
#                                                  URL priceLow priceHigh  \
# 0  https://www.tripadvisor.com//Restaurant_Review...      NaN       NaN
# 1  https://www.tripadvisor.com//Restaurant_Review...  ₩12,953   ₩38,860
# 2  https://www.tripadvisor.com//Restaurant_Review...   ₩3,886   ₩64,767
# 3  https://www.tripadvisor.com//Restaurant_Review...      NaN       NaN
# 4  https://www.tripadvisor.com//Restaurant_Review...   ₩2,124   ₩26,554
#
#                                              reviews  \
# 0  ['I came in for pizza because they look like t...
# 1  ["I was looking for some decent seafoods resta...
# 2  ['Beautiful dinner and great service! All meal...
# 3  ['Great service. Good price and good food. The...
# 4  ['Quynh was our server and took great care of ...
#
#                                               adress rating  \
# 0  124 Bạch Đằng, Hải Châu, Đà Nẵng, Da Nang Vietnam   5.0
# 1  99 Vo Nguyen Giap Street Ngu Hanh Son District...   5.0
# 2  20 Dong Da 7F New Orient Hotel, Thuan Phuoc Wa...   5.0
# 3  134 Phan Châu Trinh, Phước Ninh, Hải Châu, Đà ...   5.0
# 4   53 Phan Thuc Duyen, My An, Da Nang 50507 Vietnam   5.0
#
#                     TEL                                             images
# 0          +84989232315  ['https://media-cdn.tripadvisor.com/media/phot...
# 1      +84 236 3919 999  ['https://media-cdn.tripadvisor.com/media/phot...
# 2      +84 236 3828 828  ['https://media-cdn.tripadvisor.com/media/phot...
# 3      +84 236 3569 000  ['https://media-cdn.tripadvisor.com/media/phot...
# 4  Improve this listing  ['https://media-cdn.tripadvisor.com/media/vide...

# %%
# Test translate
translator = Translator()

testKo = translator.translate(df['descriptionEg'][1], dest='ko')
testVi = translator.translate(df['descriptionEg'][1], dest='vi')
print(f'Ko: {testKo.text}')
print(f'Vi: {testVi.text}')
# Out:
# Ko: Ca Chuon Co, ( 'Flying Fish') 오늘의 가장 신선한 해산물 캐치를 즐기는 현대적인 세련된 장소.다시 앉아서 휴식을 취하고 남동쪽 바다의 대담한 바다 산들 바람을칩니다.Ca Chuon Co Restaurant은 가장 정통한 전통 베트남 음식과 현지 풍미의 요리에 가장 좋은 맛을 제공합니다.
# Vi: CA Chuon Co, ('Flying Fish') một địa điểm phong cách hiện đại để thưởng thức sản phẩm hải sản tươi sống nhất trong ngày.Ngồi lại, thư giãn và đắm mình trong những cơn gió biển của Biển Đông Nam.Nhà hàng CA Chuon Co sẽ cung cấp cho bạn các món ăn truyền thống chính thống nhất của Việt Nam và hương vị tốt nhất của hương vị địa phương của chúng tôi cho món ăn của bạn.

# %%
def translate(text, desc: str):
    translator = Translator()
    time.sleep(rd.uniform(1.5, 2.5))
    if pd.isnull(text):
        return np.NaN
    else:
        return translator.translate(text, dest=desc).text

# %%
temp = pd.DataFrame({'text': ['Hello', 'World', 'Python', 'Pandas', 'Numpy', np.NaN]})
test = temp['text'].progress_apply(translate, desc='ko')
print(test)
# Out:
# 100%|██████████| 6/6 [00:14<00:00,  2.46s/it]
# 0    안녕하세요
# 1       세계
# 2      파이썬
# 3       팬더
# 4    Numpy
# 5      NaN
# Name: text, dtype: object

# %%
# translate category
df["categoryKo"] = df["categoryKo"].progress_apply(translate, desc='ko')
df["categoryVi"] = df["categoryVi"].progress_apply(translate, desc='vi')

# translate description
df["descriptionKo"] = df["descriptionKo"].progress_apply(translate, desc='ko')
df["descriptionVi"] = df["descriptionVi"].progress_apply(translate, desc='vi')

# translate address
df["addressKo"] = df["addressKo"].progress_apply(translate, desc='ko')
df["addressVi"] = df["addressVi"].progress_apply(translate, desc='vi')

df

# %%
df.to_csv("./translatedDataset.csv")

# %%
df = pd.read_csv("./translatedDataset.csv")
df
# Out:
#      Unnamed: 0                                          name   categoryEg  \
# 0             0                      Cardi Pizzeria Bach Dang     American
# 1             1  Ca Chuon Co Vietnamese - Seafood Restaurant.         Cafe
# 2             2                    Bistecca Restaurant Danang      Italian
# 3             3                           3 Big - Nướng & Lẩu        Pizza
# 4             4                    Thìa Gỗ Restaurant Da Nang   Vietnamese
# ..          ...                                           ...          ...
# 582         582            Lang Ca - Fresh Seafood Restaurant   Vietnamese
# 583         583                             Cua Do Restaurant      Seafood
# 584         584             SOHO Buffet & Alacarte Restaurant     Japanese
# 585         585            Danang Tower Steakhouse & Soju Bar   Steakhouse
# 586         586                                   Burger King  Quick Bites
#
#     categoryKo           categoryVi  \
# 0        미국 사람             Người Mỹ
# 1           카페          Quán cà phê
# 2      이탈리아 사람              người Ý
# 3           피자                pizza
# 4         베트남어           Tiếng Việt
# ..         ...                  ...
# 582       베트남어           Tiếng Việt
# 583         해물              Hải sản
# 584        일본어           tiếng Nhật
# 585   스테이크 하우스     Nhà hàng bít tết
# 586      빠른 물린  Vết cắn nhanh chóng
#
#                                          descriptionEg  \
# 0    Premium Steak & Pizza Certified Imported Steak...
# 1    Ca Chuon Co, ('flying fish') a modern stylish ...
# 2    Bistecca – Italian restaurant offering the ori...
# 3    3 BiG - Nướng & Lẩu Nhà hàng BBQ - Thịt nướng ...
# 4                                                  NaN
# ..                                                 ...
# 582                                                NaN
# 583                                                NaN
# 584  As the world of food up to nearly 300 dishes i...
# 585  From the mouthwatering seafood to the tender g...
# 586                                                NaN
#
#                                          descriptionKo  \
# 0    프리미엄 스테이크 및 피자 인증 수입 스테이크, 신선한 이탈리아 표준 피자, 프리미...
# 1    Ca Chuon Co, ( 'Flying Fish') 오늘의 가장 신선한 해산물 캐...
# 2    Bistecca-이탈리아 레스토랑은 다양한 이탈리아 및 국제 와인을 갖춘 오리지널 ...
# 3    3 BIG -BBQ 레스토랑 및 핫 포트 - 뷔페 - 한국 뷔페 - 뷔페 Tobok...
# 4                                                  NaN
# ..                                                 ...
# 582                                                NaN
# 583                                                NaN
# 584  현대 뷔페 레스토랑 인 소호 (Soho)는 아시아와 유럽 요리를 포함한 거의 300...
# 585  군침이 도는 해산물에서 부드러운 구운 스테이크에 이르기까지 모든 요리는 37 층 호...
# 586                                                NaN
#
#                                          descriptionVi  \
# 0    Premium Steak & Pizza Certified Imported Steak...
# 1    CA Chuon Co, ('Flying Fish') một địa điểm phon...
# 2    Bistecca-Nhà hàng Ý cung cấp hương vị tại nhà ...
# 3    3 BiG - Nướng & Lẩu Nhà hàng BBQ - Thịt nướng ...
# 4                                                  NaN
# ..                                                 ...
# 582                                                NaN
# 583                                                NaN
# 584  Vì thế giới thực phẩm lên tới gần 300 món ăn b...
# 585  Từ hải sản hấp dẫn đến bít tết nướng, tất cả c...
# 586                                                NaN
#
#                                                   time  \
# 0    ['Sun:12:00 AM - 11:59 PM', 'Mon:12:00 AM - 11...
# 1    ['Sun:06:00 AM - 10:00 PM', 'Mon:06:00 AM - 10...
# 2    ['Sun:06:00 AM - 10:00 PM', 'Mon:06:00 AM - 10...
# 3    ['Sun:11:00 AM - 11:00 PM', 'Mon:11:00 AM - 10...
# 4    ['Sun:10:00 AM - 10:00 PM', 'Mon:10:00 AM - 10...
# ..                                                 ...
# 582                                                NaN
# 583                                                NaN
# 584  ['Sun : 10:30 AM - 10:00 PM', 'Mon : 10:30 AM ...
# 585                                                NaN
# 586                                                NaN
#
#                                                    URL priceLow priceHigh  \
# 0    https://www.tripadvisor.com//Restaurant_Review...      NaN       NaN
# 1    https://www.tripadvisor.com//Restaurant_Review...  ₩12,953   ₩38,860
# 2    https://www.tripadvisor.com//Restaurant_Review...   ₩3,886   ₩64,767
# 3    https://www.tripadvisor.com//Restaurant_Review...      NaN       NaN
# 4    https://www.tripadvisor.com//Restaurant_Review...   ₩2,124   ₩26,554
# ..                                                 ...      ...       ...
# 582  https://www.tripadvisor.com//Restaurant_Review...      NaN       NaN
# 583  https://www.tripadvisor.com//Restaurant_Review...      NaN       NaN
# 584  https://www.tripadvisor.com//Restaurant_Review...      NaN       NaN
# 585  https://www.tripadvisor.com//Restaurant_Review...  ₩11,654   ₩87,403
# 586  https://www.tripadvisor.com//Restaurant_Review...      NaN       NaN
#
#                                                reviews  \
# 0    ['I came in for pizza because they look like t...
# 1    ["I was looking for some decent seafoods resta...
# 2    ['Beautiful dinner and great service! All meal...
# 3    ['Great service. Good price and good food. The...
# 4    ['Quynh was our server and took great care of ...
# ..                                                 ...
# 582  ['Services not good enough.\nThe guy at fish s...
# 583  ["This place was recommended by my guide becau...
# 584  ['Staff need to improve the service & english ...
# 585  ["Nice view. The first time I have been here w...
# 586  ['This Burger King is outrageously expensive a...
#
#                                                 adress rating  \
# 0    124 Bạch Đằng, Hải Châu, Đà Nẵng, Da Nang Vietnam   5.0
# 1    99 Vo Nguyen Giap Street Ngu Hanh Son District...   5.0
# 2    20 Dong Da 7F New Orient Hotel, Thuan Phuoc Wa...   5.0
# 3    134 Phan Châu Trinh, Phước Ninh, Hải Châu, Đà ...   5.0
# 4     53 Phan Thuc Duyen, My An, Da Nang 50507 Vietnam   5.0
# ..                                                 ...    ...
# 582  Lot 26 Vo Nguyen Giap Street My An Ward, Ngu H...   2.5
# 583  Cua Do Restaurant 233 a Nguyen Van Thoai Stree...   2.5
# 584          Lot 1, Street 2/9, Da Nang 550000 Vietnam   2.5
# 585  Đ. Trần Hưng Đạo 37/F, Vinpearl Condotel River...   1.5
# 586     Da Nang Airport Hai Chau Dist, Da Nang Vietnam   2.0
#
#                       TEL                                             images
# 0            +84989232315  ['https://media-cdn.tripadvisor.com/media/phot...
# 1        +84 236 3919 999  ['https://media-cdn.tripadvisor.com/media/phot...
# 2        +84 236 3828 828  ['https://media-cdn.tripadvisor.com/media/phot...
# 3        +84 236 3569 000  ['https://media-cdn.tripadvisor.com/media/phot...
# 4    Improve this listing  ['https://media-cdn.tripadvisor.com/media/vide...
# ..                    ...                                                ...
# 582      +84 98 331 13 68  ['https://media-cdn.tripadvisor.com/media/phot...
# 583      +84 98 316 15 16  ['https://media-cdn.tripadvisor.com/media/phot...
# 584      +84 90 868 57 89  ['https://media-cdn.tripadvisor.com/media/phot...
# 585       +(84)0896623737  ['https://media-cdn.tripadvisor.com/media/phot...
# 586      +84 511 3539 003  ['https://media-cdn.tripadvisor.com/media/phot...
#
# [587 rows x 17 columns]
